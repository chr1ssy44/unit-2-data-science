# %% [markdown]
# question 1: how many males and females survived the titanic??

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('titanic.csv')

x = ['female','male']
y = df.groupby(['Sex'])['Survived'].sum()

print(y)

plt.bar(x,y, color ='pink')
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64
# <BarContainer object of 2 artists>

# %% [markdown]
# question 2: average fare for a female from ages 20 -30?

# %%
y = df.groupby(['Sex','Age'])['Fare'].sum()
print(y)
# Out:
# Sex     Age
# female  0.75      38.5166
#         1.00      26.8750
#         2.00     259.4750
#         3.00      62.6542
#         4.00     114.1417
#                    ...
# male    70.00     81.5000
#         70.50      7.7500
#         71.00     84.1584
#         74.00      7.7750
#         80.00     30.0000
# Name: Fare, Length: 145, dtype: float64

# %% [markdown]
# question 3: How many people were in each embarked letter?

# %%
x = ['S']
y = df.groupby(['Sex', 'Embarked'])['Age'].count()

print(y)

plt.bar(x,y)
# Out:
# Sex     Embarked
# female  C            61
#         Q            12
#         S           186
# male    C            69
#         Q            16
#         S           368
# Name: Age, dtype: int64
# <BarContainer object of 6 artists>
